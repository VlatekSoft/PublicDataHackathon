# %%
import pandas as pd

# %%
df = pd.read_csv('population.csv')

# %%
df.to_csv('population.csv')

# %%
df.drop(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1'], axis=1)
# Out:
#       Code                                      Name  year2017  year2018
# 0      MOW                                    Москва  11979529  12108257
# 1      MOS                        Московская область   7048084   7133620
# 2      KDA                        Краснодарский край   5330181   5404273
# 3      SPE   Санкт-Петербург и Ленинградская область   5028000   5131942
# 4      SVE                      Свердловская область   4315830   4320677
# 5      ROS                        Ростовская область   4254613   4245532
# 6       BA                   Республика Башкортостан   4060957   4069698
# 7       TA                      Республика Татарстан   3822038   3838230
# 8      TYU                         Тюменская область   3510683   3546345
# 9      CHE                       Челябинская область   3485272   3490053
# 10     NIZ                     Нижегородская область   3289841   3281496
# 11     SAM                         Самарская область   3213289   3211187
# ...

# %%
df.to_csv('population.csv')

# %%
import requests

# %%
r = requests.get('https://creator.zoho.com/api/json/project13/view/Untitled_Form_Report?authtoken=7adc795c07cade9d66827aaa5ba8e369&scope=creatorapi&zc_ownername=zoho_vlad179&raw=true')

# %%
r.json()
# Out:
# {'Untitled_Form': [{'NUMBER': 7,
#    'DROP_DOWN1': '',
#    'NUMBER1': 2018,
#    'NUMBER2': '',
#    'DROP_DOWN': 'Армения',
#    'ID': '3724721000000026575',
#    'DROP_DOWN2': ''},
#   {'NUMBER': 6,
#    'DROP_DOWN1': '',
#    'NUMBER1': 2018,
#    'NUMBER2': '',
#    'DROP_DOWN': 'Армения',
#    'ID': '3724721000000026571',
#    'DROP_DOWN2': ''},
#   {'NUMBER': 5,
#    'DROP_DOWN1': '',
#    'NUMBER1': 2018,
#    'NUMBER2': '',
#    'DROP_DOWN': 'Армения',
#    'ID': '3724721000000026567',
#    'DROP_DOWN2': ''},
#   {'NUMBER': 4,
#    'DROP_DOWN1': '',
#    'NUMBER1': 2018,
#    'NUMBER2': '',
#    'DROP_DOWN': 'Армения',
#    'ID': '3724721000000026563',
#    'DROP_DOWN2': ''},
#   {'NUMBER': 3,
#    'DROP_DOWN1': '',
#    'NUMBER1': 2018,
#    'NUMBER2': '',
#    'DROP_DOWN': 'Армения',
#    'ID': '3724721000000026559',
#    'DROP_DOWN2': ''},
#   {'NUMBER': 2,
#    'DROP_DOWN1': '',
#    'NUMBER1': 2018,
#    'NUMBER2': 1,
#    'DROP_DOWN': 'Армения',
# ...

# %%
data = pd.DataFrame(r.json()['Untitled_Form'])

# %%
a = sorted(data[data['DROP_DOWN1'] != '']['DROP_DOWN1'].unique())

# %%
b = sorted(df['Name'].unique())

# %%
# Out:
# 0                                       Москва
# 1                           Московская область
# 2                           Краснодарский край
# 3      Санкт-Петербург и Ленинградская область
# 4                         Свердловская область
# 5                           Ростовская область
# 6                      Республика Башкортостан
# 7                         Республика Татарстан
# 8                            Тюменская область
# 9                          Челябинская область
# 10                       Нижегородская область
# 11                           Самарская область
# 12                         Республика Дагестан
# 13                           Красноярский край
# 14                         Ставропольский край
# 15                         Кемеровская область
# 16                       Новосибирская область
# 17                               Пермский край
# 18                       Волгоградская область
# 19                       Волгоградская область
# ...

# %%
df['Name'] = df44['Name']

# %%
df.to_csv('population.csv')

# %%
pd.io.clipboards.to_clipboard(pd.DataFrame(a))

# %%
df44 = pd.read_clipboard()

# %%
df44
# Out:
#       Code                                      Name
# 0      MOW                                    Москва
# 1      MOS                        Московская область
# 2      KDA                        Краснодарский край
# 3      SPE   Санкт-Петербург и Ленинградская область
# 4      SVE                      Свердловская область
# 5      ROS                        Ростовская область
# 6       BA                   Республика Башкортостан
# 7       TA                      Республика Татарстан
# 8      TYU                         Тюменская область
# 9      CHE                       Челябинская область
# 10     NIZ                     Нижегородская область
# 11     SAM                         Самарская область
# 12      DA                       Республика Дагестан
# 13     KYA                         Красноярский край
# 14     STA                       Ставропольский край
# 15     KEM                       Кемеровская область
# 16     NVS                     Новосибирская область
# ...

# %%
data.tail()
# Out:
#      DROP_DOWN DROP_DOWN1 DROP_DOWN2                   ID  NUMBER  NUMBER1  \
# 1139    Россия     Москва         77  3724721000000022019      11     2017
# 1140    Россия     Москва         77  3724721000000022015      10     2017
# 1141    Россия     Москва         77  3724721000000022011       9     2017
# 1142    Россия     Москва         77  3724721000000022007       8     2017
# 1143    Россия     Москва         77  3724721000000022003       7     2017
#
#      NUMBER2
# 1139     129
# 1140     134
# 1141     129
# 1142     123
# 1143     124

# %%
data.columns = ['Страна', 'Регион', 'Region_ID', 'ID', 'Месяц', 'Год', 'Количество']

# %%
df3 = data[(data['Количество'] != '') & (data['Регион'] != '')].groupby(['Регион', 'Год'])['Количество'].sum()

# %%
c.reset_index()
# Out:
#                                       Регион   Год  Количество
# 0                             Алтайский край  2017           1
# 1                             Алтайский край  2018           1
# 2                           Амурская область  2017           1
# 3                      Архангельская область  2017           2
# 4                      Архангельская область  2018           1
# 5                       Астраханская область  2017           3
# 6                       Астраханская область  2018           1
# 7                       Белгородская область  2017           3
# 8                       Владимирская область  2017           1
# 9                       Владимирская область  2018           1
# 10                       Воронежская область  2017           5
# 11                       Воронежская область  2018           2
# 12                        Забайкальский край  2017           1
# 13                        Забайкальский край  2018           1
# ...

# %%
df3
# Out:
# Регион                                    Год
# Алтайский край                            2017      1
#                                           2018      1
# Амурская область                          2017      1
# Архангельская область                     2017      2
#                                           2018      1
# Астраханская область                      2017      3
#                                           2018      1
# Белгородская область                      2017      3
# Владимирская область                      2017      1
#                                           2018      1
# Воронежская область                       2017      5
#                                           2018      2
# Забайкальский край                        2017      1
#                                           2018      1
# Ивановская область                        2017      1
#                                           2018      2
# Иркутская область                         2017      1
# ...

# %%
df = df.drop(['year1959', 'year1970', 'year1970', 'year1989', 'year2002', 'year2010', 'year1979'], axis=1)

# %%
df.columns = ['Unnamed: 0', 'Code', 'Name', 'year2017', 'year2018']

# %%
df.to_csv('population.csv')

# %%
# !mv ../index2.html ../index.html
